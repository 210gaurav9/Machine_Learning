# %%
import pandas as pd

# %%
pr=pd.read_csv("Iris.csv")

# %%
pr
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
pr.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
pr["Season"]="Summer"

# %%
pr.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Season
# 0  Summer
# 1  Summer
# 2  Summer
# 3  Summer
# 4  Summer

# %%
pr.insert(2,column="Colour",value="Yellow" "Red")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-7ad9117a5773> in <module>
# ----> 1 pr.insert(2,column="Colour",value="Yellow" "Red")
#
# c:\users\gaurav ghosh\appdata\local\programs\python\python37\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3589         self._ensure_valid_index(value)
#    3590         value = self._sanitize_column(column, value, broadcast=False)
# -> 3591         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3592
#    3593     def assign(self, **kwargs):
#
# c:\users\gaurav ghosh\appdata\local\programs\python\python37\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# ...

# %%
pr.head()
# Out:
#    Id  SepalLengthCm     Colour  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   1            5.1  YellowRed           3.5            1.4           0.2
# 1   2            4.9  YellowRed           3.0            1.4           0.2
# 2   3            4.7  YellowRed           3.2            1.3           0.2
# 3   4            4.6  YellowRed           3.1            1.5           0.2
# 4   5            5.0  YellowRed           3.6            1.4           0.2
#
#        Species  Season
# 0  Iris-setosa  Summer
# 1  Iris-setosa  Summer
# 2  Iris-setosa  Summer
# 3  Iris-setosa  Summer
# 4  Iris-setosa  Summer

# %%
pr.insert(2,column="Color",value="Yellow")

# %%
pr.head()
# Out:
#    Id  SepalLengthCm   Color     Colour  SepalWidthCm  PetalLengthCm  \
# 0   1            5.1  Yellow  YellowRed           3.5            1.4
# 1   2            4.9  Yellow  YellowRed           3.0            1.4
# 2   3            4.7  Yellow  YellowRed           3.2            1.3
# 3   4            4.6  Yellow  YellowRed           3.1            1.5
# 4   5            5.0  Yellow  YellowRed           3.6            1.4
#
#    PetalWidthCm      Species  Season
# 0           0.2  Iris-setosa  Summer
# 1           0.2  Iris-setosa  Summer
# 2           0.2  Iris-setosa  Summer
# 3           0.2  Iris-setosa  Summer
# 4           0.2  Iris-setosa  Summer
