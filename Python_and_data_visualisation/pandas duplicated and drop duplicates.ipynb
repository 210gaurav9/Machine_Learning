# %%
import pandas as pd

df=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.sort_values("Age",inplace=True)
df.head()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1311   18        No         Non-Travel       1431  Research & Development
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 972    18        No         Non-Travel       1124  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 296    18       Yes      Travel_Rarely        230  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1311                14          3        Medical              1
# 457                  5          3      Marketing              1
# 972                  1          3  Life Sciences              1
# 301                 10          3        Medical              1
# 296                  3          3  Life Sciences              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df["Age"].duplicated()
# Out:
# 1311    False
# 457      True
# 972      True
# 301      True
# 296      True
#         ...
# 536     False
# 427      True
# 411      True
# 879      True
# 1209     True
# Name: Age, Length: 1470, dtype: bool

# %%
df[df["Age"].duplicated()]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 457    18       Yes  Travel_Frequently       1306                   Sales
# 972    18        No         Non-Travel       1124  Research & Development
# 301    18        No      Travel_Rarely        812                   Sales
# 296    18       Yes      Travel_Rarely        230  Research & Development
# 1153   18       Yes  Travel_Frequently        544                   Sales
# ...   ...       ...                ...        ...                     ...
# 232    59        No      Travel_Rarely        818         Human Resources
# 427    60        No  Travel_Frequently       1499                   Sales
# 411    60        No      Travel_Rarely        422  Research & Development
# 879    60        No      Travel_Rarely        696                   Sales
# 1209   60        No      Travel_Rarely        370  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
mask=~df["Age"].duplicated()
df[mask]
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1311   18        No         Non-Travel       1431  Research & Development
# 909    19        No      Travel_Rarely        265  Research & Development
# 689    20       Yes      Travel_Rarely        129  Research & Development
# 815    21        No      Travel_Rarely        984  Research & Development
# 1137   22        No         Non-Travel        457  Research & Development
# 1127   23        No      Travel_Rarely        977  Research & Development
# 113    24        No      Travel_Rarely       1127  Research & Development
# 911    25       Yes  Travel_Frequently        599                   Sales
# 733    26        No      Travel_Rarely       1066  Research & Development
# 537    27        No  Travel_Frequently        294  Research & Development
# 764    28        No      Travel_Rarely       1144                   Sales
# 1313   29       Yes      Travel_Rarely        350         Human Resources
# ...

# %%
len(df[mask])
# Out:
# 43

# %%
df.drop_duplicates(["Age"])
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1311   18        No         Non-Travel       1431  Research & Development
# 909    19        No      Travel_Rarely        265  Research & Development
# 689    20       Yes      Travel_Rarely        129  Research & Development
# 815    21        No      Travel_Rarely        984  Research & Development
# 1137   22        No         Non-Travel        457  Research & Development
# 1127   23        No      Travel_Rarely        977  Research & Development
# 113    24        No      Travel_Rarely       1127  Research & Development
# 911    25       Yes  Travel_Frequently        599                   Sales
# 733    26        No      Travel_Rarely       1066  Research & Development
# 537    27        No  Travel_Frequently        294  Research & Development
# 764    28        No      Travel_Rarely       1144                   Sales
# 1313   29       Yes      Travel_Rarely        350         Human Resources
# ...
