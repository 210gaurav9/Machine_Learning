# %%
import pandas as pd

# %%
p=pd.read_csv("Iris.csv")

# %%
p
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
p["PetalWidthCm"]=p["PetalWidthCm"].fillna(0).astype(int)

# %%
p["PetalWidthCm"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    1
# 147    2
# 148    2
# 149    1
# Name: PetalWidthCm, Length: 150, dtype: int32

# %%
p.head(120)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4             0
# 1      2            4.9           3.0            1.4             0
# 2      3            4.7           3.2            1.3             0
# 3      4            4.6           3.1            1.5             0
# 4      5            5.0           3.6            1.4             0
# ..   ...            ...           ...            ...           ...
# 115  116            6.4           3.2            5.3             2
# 116  117            6.5           3.0            5.5             1
# 117  118            7.7           3.8            6.7             2
# 118  119            7.7           2.6            6.9             2
# 119  120            6.0           2.2            5.0             1
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
p["PetalWidthCm"].rank(ascending=True).astype(int)
# Out:
# 0       25
# 1       25
# 2       25
# 3       25
# 4       25
#       ...
# 145    136
# 146     86
# 147    136
# 148    136
# 149     86
# Name: PetalWidthCm, Length: 150, dtype: int32

# %%
p.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4             0  Iris-setosa
# 1   2            4.9           3.0            1.4             0  Iris-setosa
# 2   3            4.7           3.2            1.3             0  Iris-setosa
# 3   4            4.6           3.1            1.5             0  Iris-setosa
# 4   5            5.0           3.6            1.4             0  Iris-setosa
#
#    petalWidth Rank
# 0              125
# 1              125
# 2              125
# 3              125
# 4              125

# %%
p.insert(5,column="petalWidthRank",value=p["PetalWidthCm"].rank(ascending=False).astype(int))

# %%
p.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0   1            5.1           3.5            1.4             0
# 1   2            4.9           3.0            1.4             0
# 2   3            4.7           3.2            1.3             0
# 3   4            4.6           3.1            1.5             0
# 4   5            5.0           3.6            1.4             0
#
#    petalWidthRank      Species  petalWidth Rank
# 0             125  Iris-setosa              125
# 1             125  Iris-setosa              125
# 2             125  Iris-setosa              125
# 3             125  Iris-setosa              125
# 4             125  Iris-setosa              125

# %%
p.sort_values("petalWidthRank",ascending=True)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 148  149            6.2           3.4            5.4             2
# 113  114            5.7           2.5            5.0             2
# 117  118            7.7           3.8            6.7             2
# 118  119            7.7           2.6            6.9             2
# 112  113            6.8           3.0            5.5             2
# ..   ...            ...           ...            ...           ...
# 29    30            4.7           3.2            1.6             0
# 28    29            5.2           3.4            1.4             0
# 27    28            5.2           3.5            1.5             0
# 38    39            4.4           3.0            1.3             0
# 0      1            5.1           3.5            1.4             0
#
#      petalWidthRank         Species  petalWidth Rank
# 148              15  Iris-virginica               15
# 113              15  Iris-virginica               15
# ...
