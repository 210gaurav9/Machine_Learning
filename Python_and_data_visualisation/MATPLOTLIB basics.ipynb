# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7]

y=[1,2,3,4,5,6,7]

plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("just a linear graph")
plt.show()

# %%
x=[1.5,2.5,14,1,2,8,6.2]
y=[2,6,10,3,5,1.4,12]
plt.plot(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("curiosity")
plt.show()
