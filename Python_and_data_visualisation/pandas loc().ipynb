# %%
import pandas as pd
df=pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df
# Out:
#     Attrition     BusinessTravel  DailyRate              Department  \
# Age
# 41        Yes      Travel_Rarely       1102                   Sales
# 49         No  Travel_Frequently        279  Research & Development
# 37        Yes      Travel_Rarely       1373  Research & Development
# 33         No  Travel_Frequently       1392  Research & Development
# 27         No      Travel_Rarely        591  Research & Development
# ..        ...                ...        ...                     ...
# 36         No  Travel_Frequently        884  Research & Development
# 39         No      Travel_Rarely        613  Research & Development
# 27         No      Travel_Rarely        155  Research & Development
# 49         No  Travel_Frequently       1023                   Sales
# 34         No      Travel_Rarely        628  Research & Development
#
#      DistanceFromHome  Education EducationField  EmployeeCount  \
# Age
# 41                  1          2  Life Sciences              1
# ...

# %%
df.loc[41]
# Out:
#     Attrition     BusinessTravel  DailyRate              Department  \
# Age
# 41        Yes      Travel_Rarely       1102                   Sales
# 41        Yes      Travel_Rarely       1360  Research & Development
# 41         No      Travel_Rarely        802                   Sales
# 41         No  Travel_Frequently        857  Research & Development
# 41         No      Travel_Rarely        933  Research & Development
# 41         No      Travel_Rarely        465  Research & Development
# 41        Yes      Travel_Rarely       1356                   Sales
# 41         No      Travel_Rarely        896                   Sales
# 41         No      Travel_Rarely       1411  Research & Development
# 41         No      Travel_Rarely        334                   Sales
# 41         No      Travel_Rarely        483  Research & Development
# 41        Yes  Travel_Frequently        143                   Sales
# 41         No      Travel_Rarely        645                   Sales
# ...

# %%
df.loc[20]
# Out:
#     Attrition     BusinessTravel  DailyRate              Department  \
# Age
# 20        Yes  Travel_Frequently        871  Research & Development
# 20         No      Travel_Rarely        959  Research & Development
# 20        Yes      Travel_Rarely       1362  Research & Development
# 20        Yes      Travel_Rarely        500                   Sales
# 20        Yes      Travel_Rarely        129  Research & Development
# 20        Yes      Travel_Rarely       1097  Research & Development
# 20        Yes  Travel_Frequently        769                   Sales
# 20         No      Travel_Rarely        805  Research & Development
# 20         No      Travel_Rarely        654                   Sales
# 20         No      Travel_Rarely       1141                   Sales
# 20         No      Travel_Rarely        727                   Sales
#
#      DistanceFromHome  Education    EducationField  EmployeeCount  \
# Age
# 20                  6          3     Life Sciences              1
# ...

# %%
df.loc[18:20]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-6d8c4b60800e> in <module>
# ----> 1 df.loc[18:20]
#
# c:\users\gaurav ghosh\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# c:\users\gaurav ghosh\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1795         if isinstance(key, slice):
#    1796             self._validate_key(key, axis)
# -> 1797             return self._get_slice_axis(key, axis=axis)
#    1798         elif com.is_bool_indexer(key):
# ...
